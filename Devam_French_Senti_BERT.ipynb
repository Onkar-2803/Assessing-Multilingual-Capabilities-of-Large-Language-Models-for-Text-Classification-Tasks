# %%
import pandas as pd

df = pd.read_csv("french_tweets.csv", error_bad_lines=False)
# show the dataframe
df
# Out:
# <ipython-input-1-49ab51a49d93>:3: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv("french_tweets.csv", error_bad_lines=False)
#          label                                               text
# 0            0  - Awww, c'est un bummer. Tu devrais avoir davi...
# 1            0  Est contrarié qu'il ne puisse pas mettre à jou...
# 2            0  J'ai plongé plusieurs fois pour la balle. A ré...
# 3            0  Tout mon corps a des démangeaisons et comme si...
# 4            0  Non, il ne se comporte pas du tout. je suis en...
# ...        ...                                                ...
# 1526719      1  Oui, cela fonctionne mieux que de l'attendre à...
# 1526720      1  Je viens de me réveiller. Ne pas avoir d'école...
# 1526721      1  Thewdb.com - très cool d'entendre les vieilles...
# 1526722      1  Êtes-vous prêt pour votre mojo makeover? Deman...
# ...

# %%
def swap_columns(df, col1, col2):
    col_list = list(df.columns)
    x, y = col_list.index(col1), col_list.index(col2)
    col_list[y], col_list[x] = col_list[x], col_list[y]
    df = df[col_list]
    return df

#swap points and rebounds columns
df = swap_columns(df, 'text', 'label')

# %%
df
# Out:
#                                                       text  label
# 0        - Awww, c'est un bummer. Tu devrais avoir davi...      0
# 1        Est contrarié qu'il ne puisse pas mettre à jou...      0
# 2        J'ai plongé plusieurs fois pour la balle. A ré...      0
# 3        Tout mon corps a des démangeaisons et comme si...      0
# 4        Non, il ne se comporte pas du tout. je suis en...      0
# ...                                                    ...    ...
# 1526719  Oui, cela fonctionne mieux que de l'attendre à...      1
# 1526720  Je viens de me réveiller. Ne pas avoir d'école...      1
# 1526721  Thewdb.com - très cool d'entendre les vieilles...      1
# 1526722  Êtes-vous prêt pour votre mojo makeover? Deman...      1
# 1526723  Joyeux 38ème anniversaire à mon livre de tous ...      1
#
# [1526724 rows x 2 columns]

# %%
df
# Out:
#                                                       text  label
# 0        - Awww, c'est un bummer. Tu devrais avoir davi...      0
# 1        Est contrarié qu'il ne puisse pas mettre à jou...      0
# 2        J'ai plongé plusieurs fois pour la balle. A ré...      0
# 3        Tout mon corps a des démangeaisons et comme si...      0
# 4        Non, il ne se comporte pas du tout. je suis en...      0
# ...                                                    ...    ...
# 1526719  Oui, cela fonctionne mieux que de l'attendre à...      1
# 1526720  Je viens de me réveiller. Ne pas avoir d'école...      1
# 1526721  Thewdb.com - très cool d'entendre les vieilles...      1
# 1526722  Êtes-vous prêt pour votre mojo makeover? Deman...      1
# 1526723  Joyeux 38ème anniversaire à mon livre de tous ...      1
#
# [1526724 rows x 2 columns]

# %%
df_subset = df[df["label"] == 1][:500]
df_subset = df_subset.append(df[df["label"]== 0][:500])
# Out:
# <ipython-input-8-1cb8ffce2a23>:2: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_subset = df_subset.append(df[df["label"]== 0][:500])

# %%
df_subset
# Out:
#                                                      text  label
# 771604         Je vous aime, les gars sont les meilleurs!      1
# 771605  Je me retrouve avec un de mes besties ce soir!...      1
# 771606  Merci pour l'ajout de Twitter, sunisa! Je dois...      1
# 771607  Être malade peut être vraiment bon marché quan...      1
# 771608                   Il a cet effet sur tout le monde      1
# ...                                                   ...    ...
# 495                déconnecter. J'ai besoin d'étudier....      0
# 496     Quelqu'un d'autre a des problèmes pour accéder...      0
# 497     Je n'aime absolument pas les gens qui font des...      0
# 498     Désolé, Emma, ​​Swarley est-il un poisson roug...      0
# 499     Tous mes tweets sont déjà partis, ne leur manq...      0
#
# [1000 rows x 2 columns]

# %%
df = df_subset

# %%
df
# Out:
#                                                      text  label
# 771604         Je vous aime, les gars sont les meilleurs!      1
# 771605  Je me retrouve avec un de mes besties ce soir!...      1
# 771606  Merci pour l'ajout de Twitter, sunisa! Je dois...      1
# 771607  Être malade peut être vraiment bon marché quan...      1
# 771608                   Il a cet effet sur tout le monde      1
# ...                                                   ...    ...
# 495                déconnecter. J'ai besoin d'étudier....      0
# 496     Quelqu'un d'autre a des problèmes pour accéder...      0
# 497     Je n'aime absolument pas les gens qui font des...      0
# 498     Désolé, Emma, ​​Swarley est-il un poisson roug...      0
# 499     Tous mes tweets sont déjà partis, ne leur manq...      0
#
# [1000 rows x 2 columns]

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# Assuming 'df' is your DataFrame

# Specify the features and target variable
features = df.drop('text', axis=1)
target = df['label']

# Split the data into training and test sets
train, test = train_test_split(df, test_size=0.2, random_state=42)

# train_features and train_target are the training set
# test_features and test_target are the test set

# # Optionally, if you want to convert them back to DataFrames:
# train_df = pd.concat([train_features, train_target], axis=1)
# test_df = pd.concat([test_features, test_target], axis=1)

# %%
train.head()
# Out:
#                                                      text  label
# 771633        Heureux de passer du temps avec la famille.      1
# 35      Ok, je suis malade et j'ai passé une heure ass...      0
# 195     N'a pas été fait merci aujourd'hui - je suis t...      0
# 57      J'ai du mal à dire que dallas ne va pas appara...      0
# 336     Oh je-bus! Deux ans de travail de classes sont...      0

# %%
test.head()
# Out:
#                                                      text  label
# 21      Un de mes amis m'a appelé et a demandé de la r...      0
# 237     Je suis seul, faites-moi compagnie! 22 femmes,...      0
# 240     J'ai vraiment froid. Je ne veux plus m'endormi...      0
# 160     A choisi mich st pour gagner tout du départ. J...      0
# 772015        Étudier avec des amis! C'est ma mise à jour      1

# %%
# !pip install simpletransformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.7/250.7 kB 23.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.1/7.1 MB 121.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 474.6/474.6 kB 49.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 6.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 73.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 77.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 120.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 103.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 14.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.3/184.3 kB 22.8 MB/s eta 0:00:00
# ...

# %%
from simpletransformers.classification import ClassificationModel, ClassificationArgs

# %%
model_args = ClassificationArgs()
model_args.num_train_epochs = 5
# model_args.learning_rate = 1e-5
model_args.train_batch_size = 16
model_args.eval_batch_size = 32
model_args.labels_list = [0, 1]
model_args.max_seq_length = 512
model_args.overwrite_output_dir = True
# Add more configuration options as needed

# %%
model = ClassificationModel('bert', 'dbmdz/bert-base-french-europeana-cased', num_labels = 2, args=model_args, use_cuda=True)
# Out:
# ...
# Some weights of the model checkpoint at dbmdz/bert-base-french-europeana-cased were not used when initializing BertForSequenceClassification: ['cls.predictions.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.decoder.bias', 'cls.seq_relationship.weight', 'cls.predictions.decoder.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.seq_relationship.bias']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# ...

# %%
model.train_model(train, eval_df=test)
# Out:
# /usr/local/lib/python3.10/dist-packages/simpletransformers/classification/classification_model.py:612: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   warnings.warn(
# ...
# Running Epoch 4 of 5:   0%|          | 0/50 [00:00<?, ?it/s]
# (250, 0.25931360030174255)

# %%
predictions, raw_outputs = model.predict(test["text"].values.tolist())
# Out:
# ...
#   0%|          | 0/7 [00:00<?, ?it/s]

# %%
len(predictions), len(raw_outputs)
# Out:
# (200, 200)

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report

def calculate_metrics(actual, predicted):
    accuracy = accuracy_score(actual, predicted)
    precision = precision_score(actual, predicted, average='macro')
    recall = recall_score(actual, predicted, average='macro')
    f1_macro = f1_score(actual, predicted, average='macro')
    f1_micro = f1_score(actual, predicted, average='micro')

    print(accuracy, precision, recall, f1_macro, f1_micro)

# %%
calculate_metrics(test["label"].values.tolist(), predictions)
# Out:
# 0.745 0.7519091955225442 0.7411858974358975 0.740952380952381 0.745

# %%
#model.model.save_pretrained('/content/drive/MyDrive/291I_PROJECT/bengali_hate/bengali_hate_bert')

# %%
## PERFORMANCE ON OUR TEST SET OF INTEREST

# %%
df = pd.read_csv("final_french.csv")

# %%
len(df)
# Out:
# 100

# %%
df.drop(['Unnamed: 0'], axis=1)
# Out:
#     label                                               text
# 0       1    vous êtes les bienvenus. Je vous en remerciais.
# 1       1  Être malade peut être vraiment bon marché quan...
# 2       1  N'a pas participé au concours peeps mais merci...
# 3       0  Yay! Je suis heureux pour vous avec votre trav...
# 4       0  s'endormir. Vient d'entendre parler du corps d...
# ..    ...                                                ...
# 95      1  Jour de l'école folle. Il y a une durée de 10 ...
# 96      1      Aller au lit, bonne nuit à tous et doux rêves
# 97      0  J'aurais été le premier, mais je n'avais pas d...
# 98      1  Yayyy! Lol. Je l'ai simplement demandé. Qu'a-t...
# 99      1  Je me retrouve avec un de mes besties ce soir!...
#
# [100 rows x 2 columns]

# %%
df = swap_columns(df, 'text', 'label')

# %%
df
# Out:
#     Unnamed: 0                                               text  label
# 0            0    vous êtes les bienvenus. Je vous en remerciais.      1
# 1            1  Être malade peut être vraiment bon marché quan...      1
# 2            2  N'a pas participé au concours peeps mais merci...      1
# 3            3  Yay! Je suis heureux pour vous avec votre trav...      0
# 4            4  s'endormir. Vient d'entendre parler du corps d...      0
# ..         ...                                                ...    ...
# 95          95  Jour de l'école folle. Il y a une durée de 10 ...      1
# 96          96      Aller au lit, bonne nuit à tous et doux rêves      1
# 97          97  J'aurais été le premier, mais je n'avais pas d...      0
# 98          98  Yayyy! Lol. Je l'ai simplement demandé. Qu'a-t...      1
# 99          99  Je me retrouve avec un de mes besties ce soir!...      1
#
# [100 rows x 3 columns]

# %%
df = df.drop(['Unnamed: 0'], axis=1)

# %%
predictions_subset, raw_outputs = model.predict(df["text"].values.tolist())
# Out:
# ...
#   0%|          | 0/4 [00:00<?, ?it/s]

# %%
calculate_metrics(df["label"].values.tolist(), predictions_subset)
# Out:
# 0.95 0.9516258530710557 0.95 0.949954959463517 0.9500000000000001
