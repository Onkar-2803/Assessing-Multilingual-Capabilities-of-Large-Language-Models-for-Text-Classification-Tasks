# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# train_data = pd.read_csv('/content/train.csv')
# val_data = pd.read_csv('/content/test.csv')

# %%
df = pd.read_csv("/content/drive/MyDrive/291I_PROJECT/bengali_hate/Bengali hate speech .csv")

# %%
df = df[["sentence", "hate"]]

# %%
df.head()
# Out:
#                                             sentence  hate
# 0                     যত্তসব পাপন শালার ফাজলামী!!!!!     1
# 1                  পাপন শালা রে রিমান্ডে নেওয়া দরকার     1
# 2  জিল্লুর রহমান স্যারের ছেলে এতো বড় জারজ হবে এটা...     1
# 3                শালা লুচ্চা দেখতে পাঠার মত দেখা যায়     1
# 4   তুই তো শালা গাজা খাইছচ।তুর মার হেডায় খেলবে সাকিব     1

# %%
df["text"] = df["sentence"]

# %%
df["label"] = df["hate"]

# %%
df = df.drop('sentence', axis=1)

# %%
df = df.drop('hate', axis=1)

# %%
df.head()
# Out:
#                                                 text  label
# 0                     যত্তসব পাপন শালার ফাজলামী!!!!!      1
# 1                  পাপন শালা রে রিমান্ডে নেওয়া দরকার      1
# 2  জিল্লুর রহমান স্যারের ছেলে এতো বড় জারজ হবে এটা...      1
# 3                শালা লুচ্চা দেখতে পাঠার মত দেখা যায়      1
# 4   তুই তো শালা গাজা খাইছচ।তুর মার হেডায় খেলবে সাকিব      1

# %%
len(df[df["label"]==0]), len(df[df["label"]==1])
# Out:
# (20000, 10000)

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# Assuming 'df' is your DataFrame

# Specify the features and target variable
features = df.drop('text', axis=1)
target = df['label']

# Split the data into training and test sets
train, test = train_test_split(df, test_size=0.2, random_state=42)

# train_features and train_target are the training set
# test_features and test_target are the test set

# # Optionally, if you want to convert them back to DataFrames:
# train_df = pd.concat([train_features, train_target], axis=1)
# test_df = pd.concat([test_features, test_target], axis=1)

# %%
train.head()
# Out:
#                                                     text  label
# 21753  ভাই দলমতের উর্ধে এসে একটি কথা বলি। কেউ কিছু মন...      0
# 251    পাপন শালা তুই এতো লেকচার না দিয়ে বুকে সাহস থাক...      1
# 22941                     এরোম চুর আর দেখিন খালেদার মতো।      0
# 618    সালা এই কারোনে বলি কাঙ্গাদেশের মানুষের না শুধু...      1
# 17090       মিন্নি জড়িত আছে ওর ফাঁসি চাই ওর মা জড়িত আছে      0

# %%
test.head()
# Out:
#                                                     text  label
# 2308   হাইরে হালার পরিচালক হালা নিজেও গানজা খোর আর না...      1
# 22404  কোথায় খালেদা জিয়া? আর কোথায় কাউয়া হাম বা বে ...      0
# 23397  অপু উকিল কে বলতে দিন না হয় বয়স না হলেও বারিয়ে ...      0
# 25058  বাচ্চা ছেলেদের আন্দোলন বলতে কি বোঝাল জাফর ব্যা...      0
# 2664                                        আই তোরে চুদি      1

# %%
# from sklearn.preprocessing import LabelEncoder

# train_labels = list(set(train["label"].values.tolist()))

# le = LabelEncoder()
# le.fit(train_labels)

# train_labels_encoded = le.transform(train_labels)
# label_map = dict(zip(le.classes_, le.transform(le.classes_)))

# print(f'Encoded labels: {train_labels_encoded}')
# print(f'Label mapping: {label_map}')

# %%
# map_label = {}
# for key, val in label_map.items():
#     map_label[val] = key

# map_label

# %%
# !pip install simpletransformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.7/250.7 kB 18.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.1/7.1 MB 111.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 474.6/474.6 kB 55.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 6.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 116.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 103.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 112.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 76.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 28.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.3/184.3 kB 26.9 MB/s eta 0:00:00
# ...

# %%
from simpletransformers.classification import ClassificationModel, ClassificationArgs

# %%
model_args = ClassificationArgs()
model_args.num_train_epochs = 5
# model_args.learning_rate = 1e-5
model_args.train_batch_size = 16
model_args.eval_batch_size = 32
model_args.labels_list = [i for i in range(2)]
model_args.max_seq_length = 512
model_args.overwrite_output_dir = True
# Add more configuration options as needed

# %%
model = ClassificationModel('bert', 'l3cube-pune/bengali-bert', num_labels = 2, args=model_args, use_cuda=True)
# Out:
# ...
# Some weights of the model checkpoint at l3cube-pune/bengali-bert were not used when initializing BertForSequenceClassification: ['cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.weight', 'cls.predictions.decoder.bias', 'cls.predictions.bias', 'cls.predictions.transform.dense.bias', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.decoder.weight']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# ...

# %%
model.train_model(train, eval_df=test)
# Out:
# ...
# Running Epoch 4 of 5:   0%|          | 0/1500 [00:00<?, ?it/s]
# (7500, 0.21725101806322733)

# %%
predictions, raw_outputs = model.predict(test["text"].values.tolist())
# Out:
# ...
#   0%|          | 0/188 [00:00<?, ?it/s]

# %%
len(predictions), len(raw_outputs)
# Out:
# (6000, 6000)

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report

def calculate_metrics(actual, predicted):
    accuracy = accuracy_score(actual, predicted)
    precision = precision_score(actual, predicted, average='macro')
    recall = recall_score(actual, predicted, average='macro')
    f1_macro = f1_score(actual, predicted, average='macro')
    f1_micro = f1_score(actual, predicted, average='micro')

    print(accuracy, precision, recall, f1_macro, f1_micro)

# %%
calculate_metrics(test["label"].values.tolist(), predictions)
# Out:
# 0.9018333333333334 0.8863906459651141 0.8966624920852034 0.8911084570552121 0.9018333333333334

# %%
#model.model.save_pretrained('/content/drive/MyDrive/291I_PROJECT/bengali_hate/bengali_hate_bert')

# %%
## PERFORMANCE ON OUR TEST SET OF INTEREST

# %%
test_subset = pd.read_csv("/content/drive/MyDrive/291I_PROJECT/bengali_hate/test_subset.csv")

# %%
'''test_subset = test[test["label"]==0][:50]
test_subset = test_subset.append(test[test["label"]==1][:50])'''
# Out:
# 'test_subset = test[test["label"]==0][:50]\ntest_subset = test_subset.append(test[test["label"]==1][:50])'

# %%
len(test_subset[test_subset["label"]==0]), len(test_subset[test_subset["label"]==1])
# Out:
# (50, 50)

# %%
predictions_subset, raw_outputs = model.predict(test_subset["text"].values.tolist())
# Out:
# ...
#   0%|          | 0/4 [00:00<?, ?it/s]

# %%
calculate_metrics(test_subset["label"].values.tolist(), predictions_subset)
# Out:
# 0.91 0.9114813327980731 0.9099999999999999 0.9099189270343309 0.91
