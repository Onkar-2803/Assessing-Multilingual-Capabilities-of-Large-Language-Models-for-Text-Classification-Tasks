# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# train_data = pd.read_csv('/content/train.csv')
# val_data = pd.read_csv('/content/test.csv')

# %%
df = pd.read_csv("tamil_offensive_full_train.csv", delimiter='\t', error_bad_lines=False)
# Out:
# <ipython-input-3-d1b4e2d856b8>:1: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv("tamil_offensive_full_train.csv", delimiter='\t', error_bad_lines=False)

# %%
df
# Out:
#                        movie vara level la Erika poguthu  Not_offensive  \
# 0      I love Ajith Kumar Vivegam movie inki mjy bht ...      not-Tamil
# 1              Padam nalla comedy padama irukum polaye..  Not_offensive
# 2      karthick subburaj anne .... intha padam vetri ...  Not_offensive
# 3      கவுண்டர் தேவர்.சார்பாக வெற்றி பெற வாழ்த்துக்கள் 🦁  Not_offensive
# 4      ippo intha trailer ah parkuravana oru like pod...  Not_offensive
# ...                                                  ...            ...
# 35133  Trending number #2 idhukku nammalam karanamnu ...  Not_offensive
# 35134  Movie script super, athuvum HIP HOP Tamizha mu...  Not_offensive
# 35135                       Just 3k likes for 300k likes  Not_offensive
# 35136                          Aaloo le lo. Kanda le lo.      not-Tamil
# 35137  நாமக்கல் மாவட்டம்  வன்னியர் சார்பாக திரௌபதி பட...  Not_offensive
#
#        Unnamed: 2
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# ...

# %%
df = df[["movie vara level la Erika poguthu", "Not_offensive"]]

# %%
df
# Out:
#                        movie vara level la Erika poguthu  Not_offensive
# 0      I love Ajith Kumar Vivegam movie inki mjy bht ...      not-Tamil
# 1              Padam nalla comedy padama irukum polaye..  Not_offensive
# 2      karthick subburaj anne .... intha padam vetri ...  Not_offensive
# 3      கவுண்டர் தேவர்.சார்பாக வெற்றி பெற வாழ்த்துக்கள் 🦁  Not_offensive
# 4      ippo intha trailer ah parkuravana oru like pod...  Not_offensive
# ...                                                  ...            ...
# 35133  Trending number #2 idhukku nammalam karanamnu ...  Not_offensive
# 35134  Movie script super, athuvum HIP HOP Tamizha mu...  Not_offensive
# 35135                       Just 3k likes for 300k likes  Not_offensive
# 35136                          Aaloo le lo. Kanda le lo.      not-Tamil
# 35137  நாமக்கல் மாவட்டம்  வன்னியர் சார்பாக திரௌபதி பட...  Not_offensive
#
# [35138 rows x 2 columns]

# %%
df["text"] = df["movie vara level la Erika poguthu"]

# %%
df["label"] = df["Not_offensive"]

# %%
df.head()
# Out:
#                    movie vara level la Erika poguthu  Not_offensive  \
# 0  I love Ajith Kumar Vivegam movie inki mjy bht ...      not-Tamil
# 1          Padam nalla comedy padama irukum polaye..  Not_offensive
# 2  karthick subburaj anne .... intha padam vetri ...  Not_offensive
# 3  கவுண்டர் தேவர்.சார்பாக வெற்றி பெற வாழ்த்துக்கள் 🦁  Not_offensive
# 4  ippo intha trailer ah parkuravana oru like pod...  Not_offensive
#
#                                                 text          label
# 0  I love Ajith Kumar Vivegam movie inki mjy bht ...      not-Tamil
# 1          Padam nalla comedy padama irukum polaye..  Not_offensive
# 2  karthick subburaj anne .... intha padam vetri ...  Not_offensive
# 3  கவுண்டர் தேவர்.சார்பாக வெற்றி பெற வாழ்த்துக்கள் 🦁  Not_offensive
# 4  ippo intha trailer ah parkuravana oru like pod...  Not_offensive

# %%
df = df.drop('movie vara level la Erika poguthu', axis=1)

# %%
df = df.drop('Not_offensive', axis=1)

# %%
df.head()
# Out:
#                                                 text          label
# 0  I love Ajith Kumar Vivegam movie inki mjy bht ...      not-Tamil
# 1          Padam nalla comedy padama irukum polaye..  Not_offensive
# 2  karthick subburaj anne .... intha padam vetri ...  Not_offensive
# 3  கவுண்டர் தேவர்.சார்பாக வெற்றி பெற வாழ்த்துக்கள் 🦁  Not_offensive
# 4  ippo intha trailer ah parkuravana oru like pod...  Not_offensive

# %%
labels = {'not-Tamil':-1, 'Not_offensive':0, 'Offensive_Targeted_Insult_Other':1,'Offensive_Targeted_Insult_Group':1,'Offensive_Untargetede':1, 'Offensive_Targeted_Insult_Individual': 1}

df['label'].replace(labels, inplace=True)
df.drop(df[df.label == -1].index, inplace=True)

# %%
import re

english_pattern = re.compile(r'[A-Za-z]')

df = df[~df['text'].str.contains(english_pattern)]

# %%
df
# Out:
#                                                     text  label
# 3      கவுண்டர் தேவர்.சார்பாக வெற்றி பெற வாழ்த்துக்கள் 🦁      0
# 7         ஏய் இது 96 யார் ஏமாத்தறீங்க? செம பின்னிட்டீங்க      0
# 13     இந்த படம் கண்டிப்பாக வெற்றியடைய வேண்டும் என வா...      0
# 17     செட்டியார் இன மக்கள் சார்பாக எனது சொந்த செலவில...      0
# 28     தமிழ் நாட்ல இருக்குற சாதிய பைத்தியகார கூதியானு...      1
# ...                                                  ...    ...
# 35111  கழிவறை சுத்தம் செய்வதற்கும் வீட்டை சுத்தம் செய...      0
# 35115  இந்த நேரத்தில் இந்த படம் தேவையா ? இந்து மாதத்த...      0
# 35119  வணக்கம் மாப்ள சேலத்துல இருந்து... படம் வெற்றி ...      0
# 35125  திருவாரூர் மாவட்ட தேவேந்திர குல வேளாளர் சார்பா...      0
# 35137  நாமக்கல் மாவட்டம்  வன்னியர் சார்பாக திரௌபதி பட...      0
#
# [5156 rows x 2 columns]

# %%
df.reset_index(drop=True, inplace=True)

# %%
len(df[df["label"]==0]), len(df[df["label"]==1])
# Out:
# (4182, 974)

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# Assuming 'df' is your DataFrame

# Specify the features and target variable
features = df.drop('text', axis=1)
target = df['label']

# Split the data into training and test sets
train, test = train_test_split(df, test_size=0.2, random_state=42)

# train_features and train_target are the training set
# test_features and test_target are the test set

# # Optionally, if you want to convert them back to DataFrames:
# train_df = pd.concat([train_features, train_target], axis=1)
# test_df = pd.concat([test_features, test_target], axis=1)

# %%
train.head()
# Out:
#                                                    text  label
# 2481  ஒரு ட்ரெய்லர் ஒரே ஒரு ட்ரெய்லர் பாதிக்கப்படும்...      0
# 5020  அசுரனை அழிக்க திரெளபதி வந்துட்டால்  திரெளபதி ட...      1
# 99    விர வன்னியர்களின் சார்பாக இப்படம் வெற்றி அடைய ...      0
# 2224  அனைத்து நாயுடு சமூகம் சார்பாக வாழ்த்துக்கள் !!...      0
# 2284  கோனார் சமுதாயம் சார்பாக படம் மாபெரும் வெற்றி அ...      0

# %%
test.head()
# Out:
#                                                    text  label
# 2873  இந்த படம் அனைத்து நாடக கம்பெனி நாய்களுக்கும் த...      1
# 486   நமக்கு தெரிஞ்ச இந்ததான்  அல்லு அதிகம இருக்கனும...      0
# 2794  இந்த மாதிரி ஒரு படம் எப்போது வரும் என்று காத்த...      0
# 3525  ஜாதி வெறி கூட்டங்கள் அனைத்தும் ஒன்றினைந்து பல்...      0
# 5149      தமிழன் சார்பாக படம் வெற்றி பெற  வாழ்த்துக்கள்      0

# %%
# !pip install simpletransformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 250.7/250.7 kB 8.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.1/7.1 MB 98.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 474.6/474.6 kB 51.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.6/43.6 kB 6.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 91.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 100.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.9/8.9 MB 121.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 84.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 224.5/224.5 kB 29.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 184.3/184.3 kB 27.1 MB/s eta 0:00:00
# ...

# %%
from simpletransformers.classification import ClassificationModel, ClassificationArgs

# %%
model_args = ClassificationArgs()
model_args.num_train_epochs = 5

model_args.train_batch_size = 16
model_args.eval_batch_size = 32
model_args.labels_list = [i for i in range(2)]
model_args.max_seq_length = 512
model_args.overwrite_output_dir = True

# %%
model = ClassificationModel('bert', 'l3cube-pune/tamil-bert', num_labels = 2, args=model_args, use_cuda=True)
# Out:
# ...
# Some weights of the model checkpoint at l3cube-pune/tamil-bert were not used when initializing BertForSequenceClassification: ['cls.predictions.decoder.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.decoder.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.bias', 'cls.predictions.bias']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# ...

# %%
model.train_model(train, eval_df=test)
# Out:
# /usr/local/lib/python3.10/dist-packages/simpletransformers/classification/classification_model.py:612: UserWarning: Dataframe headers not specified. Falling back to using column 0 as text and column 1 as labels.
#   warnings.warn(
# ...
# Running Epoch 4 of 5:   0%|          | 0/258 [00:00<?, ?it/s]
# (1290, 0.3703930531823358)

# %%
predictions, raw_outputs = model.predict(test["text"].values.tolist())
# Out:
# ...
#   0%|          | 0/33 [00:00<?, ?it/s]

# %%
len(predictions), len(raw_outputs)
# Out:
# (1032, 1032)

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report

def calculate_metrics(actual, predicted):
    accuracy = accuracy_score(actual, predicted)
    precision = precision_score(actual, predicted, average='macro')
    recall = recall_score(actual, predicted, average='macro')
    f1_macro = f1_score(actual, predicted, average='macro')
    f1_micro = f1_score(actual, predicted, average='micro')

    print(accuracy, precision, recall, f1_macro, f1_micro)

# %%
calculate_metrics(test["label"].values.tolist(), predictions)
# Out:
# 0.8304263565891473 0.720850498077767 0.707421942277883 0.7136710197338695 0.8304263565891473

# %%
#model.model.save_pretrained('/content/drive/MyDrive/291I_PROJECT/bengali_hate/bengali_hate_bert')

# %%
## PERFORMANCE ON OUR TEST SET OF INTEREST

# %%
test_subset = pd.read_csv("final_tamil_hate.csv")

# %%
test_subset
# Out:
#     Unnamed: 0                                               Text  Label
# 0            0  குடியுரிமைக்காக 40 வருட ஆதாரத்தை காட்டிய இசுலா...      0
# 1            1  செட்டியார் இன மக்கள் சார்பாக எனது சொந்த செலவில...      0
# 2            2  டிரெய்லர் ரிபீட் மோட் ல பாக்குறேன். அவிங்கனால ...      0
# 3            3  முத்தையா அண்ணனுக்கும் சாதி சாயம் பூசினார்கள் இ...      1
# 4            4    அப்படியே நீங்க பேண்ட மலத்தை நீங்களே அள்ளுங்கடா,      1
# ..         ...                                                ...    ...
# 95          95     வெற்றி பெற வாழ்த்துக்கள்... வெள்ளாளர்  சார்பாக      0
# 96          96  ஒரு குடும்பத்தின் கதறலை படமா மாற்றி உள்ளிர்கள்...      0
# 97          97                  போற போக்குல கிளவன வாரிடிங்களேபா..      1
# 98          98  மதுரை மாவட்டம் முத்தரையர்கள் சார்பில் படம் வெற...      0
# 99          99     ஏய் இது 96 யார் ஏமாத்தறீங்க? செம பின்னிட்டீங்க      0
#
# [100 rows x 3 columns]

# %%
'''test_subset = test[test["label"]==0][:50]
test_subset = test_subset.append(test[test["label"]==1][:50])'''
# Out:
# 'test_subset = test[test["label"]==0][:50]\ntest_subset = test_subset.append(test[test["label"]==1][:50])'

# %%
test_subset = test_subset.drop(['Unnamed: 0'], axis=1)
test_subset['text'] = test_subset['Text']
test_subset['label'] = test_subset['Label']

# %%
test_subset
# Out:
#                                                  Text  Label  \
# 0   குடியுரிமைக்காக 40 வருட ஆதாரத்தை காட்டிய இசுலா...      0
# 1   செட்டியார் இன மக்கள் சார்பாக எனது சொந்த செலவில...      0
# 2   டிரெய்லர் ரிபீட் மோட் ல பாக்குறேன். அவிங்கனால ...      0
# 3   முத்தையா அண்ணனுக்கும் சாதி சாயம் பூசினார்கள் இ...      1
# 4     அப்படியே நீங்க பேண்ட மலத்தை நீங்களே அள்ளுங்கடா,      1
# ..                                                ...    ...
# 95     வெற்றி பெற வாழ்த்துக்கள்... வெள்ளாளர்  சார்பாக      0
# 96  ஒரு குடும்பத்தின் கதறலை படமா மாற்றி உள்ளிர்கள்...      0
# 97                  போற போக்குல கிளவன வாரிடிங்களேபா..      1
# 98  மதுரை மாவட்டம் முத்தரையர்கள் சார்பில் படம் வெற...      0
# 99     ஏய் இது 96 யார் ஏமாத்தறீங்க? செம பின்னிட்டீங்க      0
#
#                                                  text  label
# 0   குடியுரிமைக்காக 40 வருட ஆதாரத்தை காட்டிய இசுலா...      0
# 1   செட்டியார் இன மக்கள் சார்பாக எனது சொந்த செலவில...      0
# ...

# %%
test_subset = test_subset.drop(['Text'], axis=1)
test_subset = test_subset.drop(['Label'], axis=1)

# %%
len(test_subset[test_subset["label"]==0]), len(test_subset[test_subset["label"]==1])
# Out:
# (50, 50)

# %%
predictions_subset, raw_outputs = model.predict(test_subset["text"].values.tolist())
# Out:
# ...
#   0%|          | 0/4 [00:00<?, ?it/s]

# %%
calculate_metrics(test_subset["label"].values.tolist(), predictions_subset)
# Out:
# 0.82 0.8472222222222222 0.8200000000000001 0.8164014687882497 0.82
