# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# train_data = pd.read_csv('/content/train.csv')
# val_data = pd.read_csv('/content/test.csv')

# %%
df = pd.read_csv("/content/drive/MyDrive/291I_PROJECT/bengali_hate/bn_senti.tsv", delimiter='\t', error_bad_lines=False)
# Out:
# <ipython-input-4-7cbff967e28a>:1: FutureWarning: The error_bad_lines argument has been deprecated and will be removed in a future version. Use on_bad_lines in the future.
#
#
#   df = pd.read_csv("/content/drive/MyDrive/291I_PROJECT/bengali_hate/bn_senti.tsv", delimiter='\t', error_bad_lines=False)
# Skipping line 5409: expected 3 fields, saw 6
# Skipping line 5444: expected 3 fields, saw 4
# Skipping line 5474: expected 3 fields, saw 4
# Skipping line 5487: expected 3 fields, saw 4
# Skipping line 5526: expected 3 fields, saw 4
# Skipping line 5607: expected 3 fields, saw 4
# Skipping line 5634: expected 3 fields, saw 4
# Skipping line 5709: expected 3 fields, saw 4
# Skipping line 5715: expected 3 fields, saw 7
# Skipping line 5814: expected 3 fields, saw 5
# Skipping line 5899: expected 3 fields, saw 5
# Skipping line 5931: expected 3 fields, saw 5
# Skipping line 5935: expected 3 fields, saw 4
# Skipping line 5964: expected 3 fields, saw 4
# ...

# %%
df.head()
# Out:
#      id                                               text class_label
# 0  2760                              আফতাব আপনি ভালো আছেন?     neutral
# 1   955  মমিনুল হক আর মুশফিক দুজনেই নিজেদের উইকেট জঘন্য...    positive
# 2    43             মিরপুর এর পিচ এ যে কেও বোলিং করতে পারে     neutral
# 3  2211  মুদ্রার ঐ পিঠ দেখা হয়ে গেল বাংলাদেশের.দেশের মা...    negative
# 4  2490                              শুভকামনা রাজ্জাক ভাই।    negative

# %%
df = df[["text", "class_label"]]

# %%
df.head()
# Out:
#                                                 text class_label
# 0                              আফতাব আপনি ভালো আছেন?     neutral
# 1  মমিনুল হক আর মুশফিক দুজনেই নিজেদের উইকেট জঘন্য...    positive
# 2             মিরপুর এর পিচ এ যে কেও বোলিং করতে পারে     neutral
# 3  মুদ্রার ঐ পিঠ দেখা হয়ে গেল বাংলাদেশের.দেশের মা...    negative
# 4                              শুভকামনা রাজ্জাক ভাই।    negative

# %%
df["label"] = df["class_label"]

# %%
df = df.drop('class_label', axis=1)

# %%
df.head()
# Out:
#                                                 text     label
# 0                              আফতাব আপনি ভালো আছেন?   neutral
# 1  মমিনুল হক আর মুশফিক দুজনেই নিজেদের উইকেট জঘন্য...  positive
# 2             মিরপুর এর পিচ এ যে কেও বোলিং করতে পারে   neutral
# 3  মুদ্রার ঐ পিঠ দেখা হয়ে গেল বাংলাদেশের.দেশের মা...  negative
# 4                              শুভকামনা রাজ্জাক ভাই।  negative

# %%
set(df["label"].values.tolist())
# Out:
# {"  ততখানির চেয়েও দু কদম দূরে দাড়িয়ে আছি।- অনির্বাণ'\tBN_NEU",
#  " longitude=92.1943473}'\tBN_NEU",
#  " আমি-তোমার জন্য যেভাবে তুমি চাও-আমি তাই হব!'\tBN_POS",
#  " ইত্যাদিনির্দেশ প্রদানে নিয়ন্ত্রকেরক্ষমতা৪৫৷ এই আইন...'\tBN_NEU",
#  " একটু তুতু... http://t.co/B78TISMmUn'\tBN_NEG",
#  " একেবারে কমদামি জাভা মোবাইলে'\tBN_NEU",
#  " ও বোন টিভি দেখছিলাম।তখন আমার হাতে রিমট ছিল এবং আমি যমুনা টিভিতে অপরাধ বিষয়ের উপর একটা...'\tBN_NEU",
#  " কাদছি নাকি ?কাদবে কি আর শুকনো আঁখি !আবার কেন দাড়ালে ঘোরে?অভিনয় করে...'\tBN_NEG",
#  " কিন্তু... http://t.co/MzIJ763fnC'\tBN_POS",
#  " চা ও।'\tBN_POS",
#  " চাঁদনী পসার রাইতে যেন আমার মরণ হয়'\tBN_POS",
#  " চুদাচুদি কর ...... বাল ছির যত পার তারপর একদিন ফুস ......... একদম সত্যি'\tBN_POS",
#  " তখন এই গোটা পৃথিবীতে শ্রেষ্ঠ উৎসাহ ও... http:/t.co/4KZM8BxQAi'\tBN_NEU",
#  " তবুও চুমোর মতো মধুর স্বাদ জগতে আর কিছুতে নেই ---- শীর্ষেন্দু মুখোপাধ্যায়'\tBN_POS",
#  " তবুও চুমোর মতো মধুর স্বাদ জগতে আর কিছুতে নেই ___শীর্ষেন্দু মুখোপাধ্যায়'\tBN_POS",
# ...

# %%
df = df[df["label"].isin(["Positive", "Negative", "Neutral"])]

# %%
df[df["label"]=="Neutral"]
# Out:
#                                                     text    label
# 3451                                         তামিম ইকবাল  Neutral
# 3452   ভালো রেজাল্ট করলেই ভালো মানুষ হওয়া যায় না।বাবা...  Neutral
# 3453                   কেমন বাংলাদেশ চায় বাংলার যুবসমাজ  Neutral
# 3455   +Neamot Ullah সহজ বাংলায় ENT specialist হলো না...  Neutral
# 3465   টিউলিপ যাতে বাংলাদেশ এ না আসে যেহেতু সে আত্মস্...  Neutral
# ...                                                  ...      ...
# 16187  RT @md0emran: মঞ্জু ভাইয়ের মার্কা কি ? ধানের ...  Neutral
# 16189  @shahanaz_rumy কিছু কিছু ক্ষেত্রে নাটক কে ও হা...  Neutral
# 16191  বড়ই আজব! যারা খারাপ খেলে বেশি গোল খেয়ে হারে ...  Neutral
# 16192  যারা রোনাল্ডো কে রন দা, রন দা করে মজা নেন, তার...  Neutral
# 16194  কোথাও একটা ভুল হচ্ছে কি ? কোথাও জনগণ ভালো নেই ...  Neutral
#
# [3172 rows x 2 columns]

# %%
import pandas as pd
from sklearn.model_selection import train_test_split

# Assuming 'df' is your DataFrame

# Specify the features and target variable
features = df.drop('text', axis=1)
target = df['label']

# Split the data into training and test sets
train, test = train_test_split(df, test_size=0.2, random_state=42)

# train_features and train_target are the training set
# test_features and test_target are the test set

# # Optionally, if you want to convert them back to DataFrames:
# train_df = pd.concat([train_features, train_target], axis=1)
# test_df = pd.concat([test_features, test_target], axis=1)

# %%
train.head()
# Out:
#                                                     text     label
# 10109           ভাল করতে পারলে কেন নিবে না। স্বাগত জানাই  Positive
# 4824   ৪০ হাজার কোটি টাকা খরচ করে পদ্মার মত অন্তত ৩ ট...   Neutral
# 12953  যখন কেউ কেউ সব বুজার পরও না বুজার ভাব করে। তার...  Positive
# 7853         বাংলাদেশের এই অবস্থার অনেকটা কারন মিডিয়া।   Negative
# 12312  ওহে মেরে বাচ্চো..!! একবার ভুল কারোগি তো মাফ কা...   Neutral

# %%
test.head()
# Out:
#                                                     text     label
# 9487                   হে আল্লাহ তুমি অদেরকে বাছাও আমিন   Positive
# 13902  দুখে দুখে জীবন গেলো ভাষাই দুখের নাও ὡ3 আমার বু...  Negative
# 7072              আইপিএল শুরুর আগে সবাই একটু চোঁটে পড়ে।  Negative
# 10243         হাসতে হাঁসতে বেহুঁশ হয়ে যাবেন অস্থির একটা   Positive
# 12397  বিএনপি , তোমরা কি হাসিনার মেচেজ টা ধরতে পেরেছো...   Neutral

# %%
# from sklearn.preprocessing import LabelEncoder

# train_labels = list(set(train["label"].values.tolist()))

# le = LabelEncoder()
# le.fit(train_labels)

# train_labels_encoded = le.transform(train_labels)
# label_map = dict(zip(le.classes_, le.transform(le.classes_)))

# print(f'Encoded labels: {train_labels_encoded}')
# print(f'Label mapping: {label_map}')

# %%
# map_label = {}
# for key, val in label_map.items():
#     map_label[val] = key

# map_label

# %%
# !pip install simpletransformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
from simpletransformers.classification import ClassificationModel, ClassificationArgs

# %%
model_args = ClassificationArgs()
model_args.num_train_epochs = 5
# model_args.learning_rate = 1e-5
model_args.train_batch_size = 16
model_args.eval_batch_size = 32
model_args.labels_list = ["Positive", "Negative", "Neutral"]
model_args.max_seq_length = 512
model_args.overwrite_output_dir = True
# Add more configuration options as needed

# %%
model = ClassificationModel('bert', 'l3cube-pune/bengali-bert', num_labels = 3, args=model_args, use_cuda=True)
# Out:
# Some weights of the model checkpoint at l3cube-pune/bengali-bert were not used when initializing BertForSequenceClassification: ['cls.predictions.transform.dense.weight', 'cls.predictions.decoder.weight', 'cls.predictions.decoder.bias', 'cls.predictions.transform.LayerNorm.weight', 'cls.predictions.transform.dense.bias', 'cls.predictions.bias', 'cls.predictions.transform.LayerNorm.bias']
# - This IS expected if you are initializing BertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing BertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# ...

# %%
model.train_model(train, eval_df=test)
# Out:
# ...
# Running Epoch 4 of 5:   0%|          | 0/604 [00:00<?, ?it/s]
# (3020, 0.4312788230693893)

# %%
predictions, raw_outputs = model.predict(test["text"].values.tolist())
# Out:
# ...
#   0%|          | 0/76 [00:00<?, ?it/s]

# %%
len(predictions), len(raw_outputs)
# Out:
# (2414, 2414)

# %%
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, classification_report

def calculate_metrics(actual, predicted):
    accuracy = accuracy_score(actual, predicted)
    precision = precision_score(actual, predicted, average='macro')
    recall = recall_score(actual, predicted, average='macro')
    f1_macro = f1_score(actual, predicted, average='macro')
    f1_micro = f1_score(actual, predicted, average='micro')

    print(accuracy, precision, recall, f1_macro, f1_micro)

# %%
calculate_metrics(test["label"].values.tolist(), predictions)
# Out:
# 0.7879038939519469 0.7827269073859009 0.7863778940901259 0.7841814546564301 0.7879038939519469

# %%
#model.model.save_pretrained('/content/drive/MyDrive/291I_PROJECT/bengali_hate/bengali_hate_bert')

# %%
## PERFORMANCE ON OUR TEST SET OF INTEREST

# %%
df
# Out:
#                                                     text     label
# 3450                      এবাভে সব অপরাধ তুলে ধরা দরকার।  Positive
# 3451                                         তামিম ইকবাল   Neutral
# 3452   ভালো রেজাল্ট করলেই ভালো মানুষ হওয়া যায় না।বাবা...   Neutral
# 3453                   কেমন বাংলাদেশ চায় বাংলার যুবসমাজ   Neutral
# 3454                                  বরাবরের মতই অসাধার  Positive
# ...                                                  ...       ...
# 16190  ী এ কে আব্দুল মোমেন বিবিসি বাংলাকে বলেছেন, "বা...  Positive
# 16191  বড়ই আজব! যারা খারাপ খেলে বেশি গোল খেয়ে হারে ...   Neutral
# 16192  যারা রোনাল্ডো কে রন দা, রন দা করে মজা নেন, তার...   Neutral
# 16193  RT @_bdLevis: বাংলাদেশ ব্যাংকের কোটি কোটি টাকা...  Negative
# 16194  কোথাও একটা ভুল হচ্ছে কি ? কোথাও জনগণ ভালো নেই ...   Neutral
#
# [12066 rows x 2 columns]

# %%
df_subset = df[df["label"]=="Positive"][:33]

# %%
df_subset = df_subset.append(df[df["label"]=="Negative"][:33])
# Out:
# <ipython-input-45-6a92ab6ecd0e>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_subset = df_subset.append(df[df["label"]=="Negative"][:33])

# %%
df_subset = df_subset.append(df[df["label"]=="Neutral"][:34])
# Out:
# <ipython-input-46-8582cc8277d4>:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_subset = df_subset.append(df[df["label"]=="Neutral"][:34])

# %%
len(df_subset)
# Out:
# 100

# %%
predictions_subset, raw_outputs = model.predict(df_subset["text"].values.tolist())
# Out:
# ...
#   0%|          | 0/4 [00:00<?, ?it/s]

# %%
calculate_metrics(df_subset["label"].values.tolist(), predictions_subset)
# Out:
# 0.87 0.8721364221364221 0.8713606654783126 0.8679768681666215 0.87
